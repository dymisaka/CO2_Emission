# %%
import pandas as pd

# %%
# df=pd.read_csv('./Old Data/data.csv')
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9167 entries, 0 to 9166
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      9167 non-null   int64
#  1   Ship type                       9167 non-null   object
#  2   length                          7919 non-null   float64
#  3   breadth                         7919 non-null   float64
#  4   gross_tonnage                   7926 non-null   float64
#  5   deadweight                      7921 non-null   float64
#  6   engine_power                    3355 non-null   object
#  7   max_speed                       9167 non-null   float64
#  8   avg_speed                       9167 non-null   float64
#  9   Time spent at sea [hours]       9167 non-null   float64
#  10  Total CO₂ emissions [m tonnes]  9167 non-null   float64
#  11  type no                         9167 non-null   float64
# ...

# %%
df=pd.read_csv('./Old Data/data.csv')
df.info()
df=df.drop(columns=['Unnamed: 0'])
df=df.drop(columns=['max_speed','Ship type','engine_power'])

df=df.dropna()
df.info()
df.to_csv('step2_data_0121.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9167 entries, 0 to 9166
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      9167 non-null   int64
#  1   Ship type                       9167 non-null   object
#  2   length                          7919 non-null   float64
#  3   breadth                         7919 non-null   float64
#  4   gross_tonnage                   7926 non-null   float64
#  5   deadweight                      7921 non-null   float64
#  6   engine_power                    3355 non-null   object
#  7   max_speed                       9167 non-null   float64
#  8   avg_speed                       9167 non-null   float64
#  9   Time spent at sea [hours]       9167 non-null   float64
#  10  Total CO₂ emissions [m tonnes]  9167 non-null   float64
#  11  type no                         9167 non-null   float64
# ...

# %%
test_data=df[['length', 'breadth', 'gross_tonnage', 'deadweight','type no']]

import pickle
with open('./rf_model.pkl', 'rb') as f:
    loaded_rf_model = pickle.load(f)
    
predicted_value = loaded_rf_model.predict(test_data)
print("预测值：", predicted_value)
# Out:
# 预测值： [12051.96        6153.6         6210.34       ...  6399.62
#   7802.25        3964.40666667]
# D:\Anaconda3\envs\ai\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
